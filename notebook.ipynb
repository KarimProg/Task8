# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics

# %%
# !unzip /content/drive/MyDrive/Coins/TheSet.zip

# %%
# %cd /content/drive/MyDrive/Coins/TheSet
# Out:
# /content/drive/MyDrive/Coins/TheSet

# %%
# !yolo task=detect mode=train data=/content/coins.yaml epochs=500 imgsz=640
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 133MB/s]
# Ultralytics YOLOv8.0.180 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
